# %% [markdown]
# # Самостоятельное задание

# %% [markdown]
# Применение различных морфологических операций к изображению и отображение результатов каждой операции. Использованные операции: дилатация (dilation), эрозия (erosion), открытие (opening), размыкание (closing), замыкание (closing), морфологический градиент (morphological gradient).

# %%
import cv2
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

# %%
image = cv2.imread("img/ind.jpeg", 0)

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (15, 15))

# %% [markdown]
# Применение операции расширения - дилатации

# %%
dilated_image = cv2.dilate(image, kernel)

# %% [markdown]
# Применение операции эрозии

# %%
eroded_image = cv2.erode(image, kernel)

# %% [markdown]
# Применение операций морфологического открытия и закрытия

# %%
opened_image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
closed_image = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)

# %% [markdown]
# Применение операции цилиндра

# %%
tophat_image = cv2.morphologyEx(image, cv2.MORPH_TOPHAT, kernel)

# %% [markdown]
# Применение операции Черная шляпа

# %%
blackhat_image = cv2.morphologyEx(image, cv2.MORPH_BLACKHAT, kernel)

# %% [markdown]
# Применение операции градиента

# %%
gradient_image = cv2.morphologyEx(image, cv2.MORPH_GRADIENT, kernel)

# %%
plt.figure(figsize=(15,15))
plt.subplot(221)
plt.imshow(image, cmap="gray")
plt.title("Исходное изображение")

plt.subplot(222)
plt.imshow(dilated_image, cmap="gray")
plt.title("Дилатация")

plt.subplot(223)
plt.imshow(eroded_image, cmap="gray")
plt.title("Эрозия")

plt.subplot(224)
plt.imshow(opened_image, cmap="gray")
plt.title("Открытие")

plt.show()

# %%
plt.figure(figsize=(15,15))
plt.subplot(221)
plt.imshow(closed_image, cmap="gray")
plt.title("Закрытие")

plt.subplot(222)
plt.imshow(tophat_image, cmap="gray")
plt.title("Морфологический градиент (Top Hat)")

plt.subplot(223)
plt.imshow(blackhat_image, cmap="gray")
plt.title("Морфологический градиент (Black Hat)")

plt.subplot(224)
plt.imshow(gradient_image, cmap="gray")
plt.title("Морфологический градиент")

plt.show();
